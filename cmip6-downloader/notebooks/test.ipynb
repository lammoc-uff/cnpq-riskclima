# %%
import xarray as xr

path1 = '/home/lammoc/Documents/projects/cmip6-downloader/downloads/INM-CM5-0/historical/Omon/tos/gr1/ensemble_all.zarr'
ds = xr.open_zarr(path1)
ds
# Out:
# <xarray.Dataset> Size: 5GB
# Dimensions:    (member: 10, time: 1980, lat: 180, lon: 360, bnds: 2)
# Coordinates:
#   * lat        (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#     lat_bnds   (lat, bnds) float64 3kB dask.array<chunksize=(180, 2), meta=np.ndarray>
#   * lon        (lon) float64 3kB 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#     lon_bnds   (lon, bnds) float64 6kB dask.array<chunksize=(360, 2), meta=np.ndarray>
#   * member     (member) <U9 360B 'r1i1p1f1' 'r3i1p1f1' ... 'r10i1p1f1'
#   * time       (time) datetime64[ns] 16kB 1850-01-16T12:00:00 ... 2014-12-16T...
#     time_bnds  (time, bnds) object 32kB dask.array<chunksize=(1980, 2), meta=np.ndarray>
# Dimensions without coordinates: bnds
# Data variables:
#     tos        (member, time, lat, lon) float32 5GB dask.array<chunksize=(1, 248, 23, 90), meta=np.ndarray>
# Attributes: (12/48)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
# ...
